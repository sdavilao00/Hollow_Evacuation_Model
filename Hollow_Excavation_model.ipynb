# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# ## Comparison of Shallow slopes (slow) vs Steep slopes (fast)

# %% [markdown]
# ### Shallow slopes

# %%
# lets find qs given that slope varies with hallow slope

# %%
# Variables for Excavation model 
#infill_rate = 2  # in meters per yr
hollow_length = 10 #in meters
#hollow_width = 8 # in meters

#total_volume = infill rate * hollow_depth *hollow_width

# %%
#find critical thickness
C = 2000 #Pa
pw = 1000 # kg/m3
ps = 2000 # kg/m3
phi = np.deg2rad(33)  #converts phi to radians 
g = 9.8  # m/s2
angle = int(input("angle in degrees "))
theta = np.deg2rad(angle) # converts theta to radians
# Out:
# angle in degrees 30

# %%
z_crit_shallow = C / ((pw*g**(np.tan(phi))*(np.cos(theta)))+(ps*g*(np.cos(theta))*(np.tan(theta) - np.tan(phi))))
print(z_crit_shallow)
# Out:
# 0.7723021988356357

# %%
# now to find how long it takes to get to this critical depth

# %%
Qin = 0.002  #m2/yr
Qout = 0.0005  #m2/yr
P = 0.0001  #m/yr
width = int(input("hollow width "))
time_shallow = z_crit_shallow / (Qin - Qout + (P*width))
print(time_shallow)
# Out:
# hollow width 5
# 386.1510994178178

# %%
#calculate the volume
volume_shallow = z_crit_shallow * width * hollow_length
print(volume_shallow)
# Out:
# 38.61510994178178

# %% [markdown]
# ### Steep hillslopes

# %%
#find critical thickness
C = 2000 #Pa
pw = 1000 # kg/m3
ps = 2000 # kg/m3
phi = np.deg2rad(33)  #converts phi to radians 
g = 9.8  # m/s2
angle = int(input("angle in degrees "))
theta = np.deg2rad(angle) # converts theta to radians
# Out:
# angle in degrees 45

# %%
z_crit_steep = C / ((pw*g**(np.tan(phi))*(np.cos(theta)))+(ps*g*(np.cos(theta))*(np.tan(theta) - np.tan(phi))))
print(z_crit_steep)
# Out:
# 0.25087571821973775

# %%
Qin = 0.002  #m2/yr
Qout = 0.0005  #m2/yr
P = 0.0001  #m/yr
width = int(input("hollow width "))
time_steep = z_crit_steep / (Qin - Qout + (P*width))
print(time_steep)
# Out:
# hollow width 5
# 125.43785910986887

# %%
#calculate volume
volume_steep = z_crit_steep * width * hollow_length
print(volume_steep)
# Out:
# 12.543785910986887

# %%
C = 2000 #Pa
pw = 1000 # kg/m3
ps = 2000 # kg/m3
g = 9.8  # m/s2

slope = np.array(np.deg2rad(range(1,61)))

for x in slope:
    z_crit = C / ((pw*g**(np.tan(33))*(np.cos(x)))
                  +(ps*g*(np.cos(x))*(np.tan(x) 
                                          - np.tan(33))))
    print(z_crit)
# Out:
# 0.0013547819386678182
# 0.001355087089679941
# 0.0013558054627084877
# 0.0013569381535490192
# 0.0013584868928245614
# 0.0013604540524492996
# 0.0013628426545180682
# 0.0013656563826838512
# 0.0013688995961033486
# 0.0013725773460494912
# 0.0013766953953096752
# 0.0013812602405098074
# 0.0013862791375271752
# 0.0013917601301800375
# 0.0013977120824089735
# 0.0014041447141947994
# 0.001411068641490691
# 0.0014184954204824998
# 0.0014264375965316882
# 0.001434908758200397
# 0.001443923596808691
# 0.0014534979720307642
# 0.001463648984100796
# 0.0014743950532713722
# 0.0014857560072491578
# 0.0014977531774253766
# 0.001510409504824379
# 0.0015237496568141766
# 0.0015378001557608408
# 0.0015525895209668318
# 0.0015681484254151845
# 0.001584509869050956
# 0.001601709370573331
# 0.0016197851799919453
# 0.0016387785145262417
# 0.0016587338208052353
# 0.001679699066766877
# 0.001701726067173236
# 0.0017248708472645793
# 0.0017491940497897103
# 0.0017747613914933615
# 0.0018016441761404098
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

## Calculate critical soil depth for a range of slopes
C = 2000 #Pa
pw = 1000 # kg/m3
ps = 2000 # kg/m3
g = 9.8  # m/s2
phi = np.deg2rad(33)

#establish an array of slope angles
slope = np.array(np.deg2rad(range(1,61)))

# create an array for critical soil depth at angles 1-60 
z_crit = []
for k in slope:
    z_value = C / ((pw*g**(np.tan(phi))*(np.cos(k)))
                          +(ps*g*(np.cos(k))*(np.tan(k) 
                                                  - np.tan(phi))))
    z_crit += [z_value]

## Create a dataframe to store these values
hollow_data = pd.DataFrame(zip(slope, z_crit))

# rename column names
hollow_data.columns = ['gradient', 'critical_soil_depth']

# now make a quick plot about this
#plt.figure()  #this is an empty canvas
plt.plot(hollow_data.gradient, hollow_data.critical_soil_depth)
plt.xlabel('Gradient')
plt.ylabel('Depth (m)')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
